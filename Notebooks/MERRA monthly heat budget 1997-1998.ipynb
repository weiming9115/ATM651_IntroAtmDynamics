# %% [markdown]
# <a name="top"></a>
#
# <div style="width:1000 px">
#
# <div style="float:right; width:300 px"><img src="https://github.com/brianmapes/ATM407/blob/master/images/Thermalwind.png?raw=true" alt="Thermal wind exercise image" style="height: 200px;"></div>
#
#
# <h1>MERRA heat budget (montly means)</h1>
# <h3>ATM 651, University of Miami</h3>
#
# * To use these Jupyter notebooks, you need to have installed the DRILSDOWN package:
# https://unidata.github.io/drilsdown/ )
#
#
# ### Activities
# 1. <a href="#Exercise1">Some math about it</a>
# 1. <a href="#Exercise2">Load an IDV bundle</a>
# 1. <a href="#Exercise3">Capture and caption a main display image</a>
# 1. <a href="#Exercise4">Capture and caption a secondary display</a>
# 1. <a href="#Exercise5">Capture and caption an animation</a>
#
# <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">

# %%
# %reload_ext ipython_IDV

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise3"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 3</b>:
#      <ul>
#       <li>**Capture an image. Describe the image. Explain in at least 3 sentences.**
#       </li>
#     </ul>
# </div>

# %%
# Your image 
# %make_image -capture legend -caption 'MERRA monthly heat budget'

# %%
# %make_image -capture legend -caption 'MERRA monthly heat budget'

# %%
# %make_image -capture legend -caption 'MERRA monthly heat budget'

# %%
# %make_image -capture legend -caption 'MERRA monthly heat budget'

# %%
# %make_image -capture legend -caption 'MERRA monthly heat budget'

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %make_movie -capture legend -caption 'Movie'

# %% [markdown]
# ## Exercise 3b answer:
#
# The animation shows ___.
#
# This means ___.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# Your image 
# %make_mage -capture legend -caption Exercise7

# %%
# Wikipedia image
from IPython.display import Image
Image("an image URL goes here")

# %% [markdown]
# # Upload this notebook to your GitHub fork (I can find it there).

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">
